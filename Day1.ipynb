# %% [markdown]
# <a href="https://colab.research.google.com/github/ImmatureSamurai/inochikaketeru/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count=0
results = []
for i in range(1,51):
  if i%3==0 and i%7==0:
    count=count+1
    results.append(i)
print(f"3の倍数かつ７の倍数は{results},個数は{count}")
