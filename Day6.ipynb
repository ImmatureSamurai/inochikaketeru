# %% [markdown]
# <a href="https://colab.research.google.com/github/ImmatureSamurai/inochikaketeru/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_range(scores_list):
    return max(scores_list)-min(scores_list)
scores_list = [72, 95, 58, 84, 41, 89, 92]
score_range = calculate_range(scores_list)
print(f"The range of the scores is: {score_range}")
# Out:
# The range of the scores is: 54
