# %% [markdown]
# <a href="https://colab.research.google.com/github/ImmatureSamurai/inochikaketeru/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count=0
results = []
limit=int(input("上限の数字を入力してください："))
for i in range(1,limit+1):
  if i%3==0 and i%7==0:
    count=count+1
    results.append(i)
print(f"3の倍数かつ７の倍数は{results},個数は{count}")
# Out:
# 上限の数字を入力してください：100
# 3の倍数かつ７の倍数は[21, 42, 63, 84],個数は4
